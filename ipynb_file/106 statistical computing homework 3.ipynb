# %%
import numpy as np
from math import *
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import plotly.plotly as py

# %% [markdown]
# 1. Generate a random sample of size 1000 from the Beta(3,2) distribution
# using the acceptance-rejection method. Graph the histogram of
# the sample with the theoretical Beta(3,2) density superimposed as the
# Figure below.

# %%
from scipy.optimize import fmin
from scipy.stats import beta
from scipy.special import gamma as gammaf
import matplotlib.pyplot as plt
import numpy



data=beta.rvs(3,2, scale=1,size=1000)
plt.hist(data,bins=20, normed = True)
xx=numpy.linspace(0,max(data),len(data))
yy = beta.pdf(xx, 3, 2, loc=0, scale=1)
plt.plot(xx, yy)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6448: UserWarning:
#
# The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.

# %%
R = 10
def f(x, R = 50):
    ans = (2/pi/R**2)*(R**2 - x**2)**0.5
    return ans
xx = np.linspace(-R, R, 50)
yy = f(xx, R) 
y = []
for i in np.arange(-R, R, 0.01):
    n = int(f(i, R)*100)
    for j in range(n):
        y.append(i)
data = np.random.choice(y, size = 1000)

plt.hist(data,bins=25, normed = True)

plt.plot(xx, yy)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6448: UserWarning:
#
# The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.

# %%
a, m = 2., 4.  # shape and mode
s = (np.random.pareto(a, 1000) + 1) * m

count, bins, _ = plt.hist(s, 100, normed=True)
fit = a*m**a / bins**(a+1)
plt.plot(bins, max(count)*fit/max(fit), linewidth=2, color='orange')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6448: UserWarning:
#
# The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.

# %%
import matplotlib.pyplot as plt
from scipy.stats import wishart, chi2
x = np.linspace(1e-5, 160, 100)
w = wishart.pdf(x, df=100, scale=1)

plt.hist(wishart.rvs(100, 1, 1000),bins=25, normed = True)
plt.plot(x, w)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6448: UserWarning:
#
# The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
